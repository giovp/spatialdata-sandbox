# %% [markdown]
# # On-Disk Data Representation

# %% [markdown]
# ## Developers resources
# - Artificial datasets covering the specification [link](https://github.com/scverse/spatialdata-notebooks/tree/main/notebooks/developers_resources/storage_format)
#     - The data is both uploaded in GitHub (link above) and to S3 ([readme from the link above](https://refined-github-html-preview.kidonng.workers.dev/scverse/spatialdata-notebooks/raw/main/notebooks/developers_resources/storage_format/index.html))
#
# ## Comparing against previous versions
# - Example of usage using the GitHub commit history function: https://github.com/scverse/spatialdata-notebooks/commits/main/notebooks/developers_resources/storage_format/transformation_scale.zarr
# - Example of usage using the GitHub compare function: https://github.com/scverse/spatialdata-notebooks/compare/f55f89a..d8e4d55

# %% [markdown]
# ## Internal testing pipeline
# ![image.png](attachment:7a441151-ee83-4474-b4da-35718d2d4234.png)
